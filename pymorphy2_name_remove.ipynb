# %%
import nltk
import pymorphy2

# Убедитесь, что необходимые ресурсы NLTK загружены
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_ru')

# Открытие файла и чтение текста
with open('/home/jovyan/work/ipynb_dock/data/belkin.txt', "r", encoding="utf-8") as f:
    text = f.read()

# Токенизация текста
tokens = nltk.word_tokenize(text)

# Инициализация морфологического анализатора
morph = pymorphy2.MorphAnalyzer()

# Функция для проверки, является ли слово именем собственным
def is_proper_noun(word):
    parsed_word = morph.parse(word)[0]
    return 'Name' in parsed_word.tag

# Извлечение имен собственных
proper_nouns = [word for word in tokens if is_proper_noun(word)]

# Создание списка часто встречаемых слов
freq_dist = nltk.FreqDist(tokens)
common_words = [word for word, freq in freq_dist.items() if freq > 5]

# Удаление имен собственных из списка часто встречаемых слов
common_words_without_proper_nouns = [word for word in common_words if not is_proper_noun(word)]

# Печать результатов
print("Имена собственные:", proper_nouns)
print("Часто встречаемые слова без имен собственных:", common_words_without_proper_nouns)
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_ru is already up-to-
# [nltk_data]       date!
# Имена собственные: ['Александр', 'Ивана', 'Митрофан', 'Марье', 'Трафилиной', 'Ивана', 'Ивану', 'Ивана', 'Иван', 'Петр', 'Пелагее', 'Иван', 'Иван', 'Ивана', 'Ивана', 'Иван', 'Ивана', 'Ивана', 'Иван', 'Иван', 'Иван', 'Иван', 'Иван', 'Иван', 'Ивана', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'мел', 'Сильвио', 'Сильвио', 'мел', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Денисом', 'Сильвио', 'Сильвио', 'Сильвио', 'пол', 'Сильвио', 'пол', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'верьхом', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Маша', 'Маше', 'Сильвио', 'Сильвио', 'Маша', 'Маша', 'Сильвио', 'Сильвио', 'Александра', 'Ипсиланти', 'Скулянами', 'валит', 'Гаврила', 'Марья', 'едине', 'Марьи', 'Владимир', 'Марья', 'Владимир', 'Марья', 'Владимира', 'Маша', 'Маша', 'Маша', 'Владимира', 'Владимир', 'Дравин', 'Владимира', 'Владимира', 'Владимир', 'Марья', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Жадрина', 'Владимир', 'Владимира', 'Мало-по-малу', 'Владимир', 'Жадрина', 'Владимир', 'Владимир', 'Владимир', 'Жадрина', 'Владимир', 'Владимир', 'Владимир', 'Жадрина', 'Владимир', 'Гаврила', 'Прасковья', 'Гаврила', 'Марьи', 'Марья', 'Маша', 'Гаврила', 'Маша', 'Маша', 'Прасковья', 'Маша', 'Маша', 'Марья', 'Владимира', 'Марьи', 'Владимира', 'Гаврилы', 'Владимир', 'Маше', 'Владимире', 'Гаврила', 'Прасковьи', 'Марья', 'Владимир', 'Маши', 'Артемизы', 'Марья', 'Марья', 'Георгием', 'Марьи', 'Марья', 'Марьей', 'Марьи', 'любовию', 'Марье', 'Прасковья', 'Марье', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'пологал', 'Марья', 'Адрияна', 'Адриян', 'Вальтер', 'Скотт', 'Адриян', 'Адриян', 'Готлиб', 'Готлиба', 'Адриян', 'Адриян', 'Адрияна', 'Дарьи', 'Адриян', 'Лотхен', 'Адриян', 'Луизы', 'Луизы', 'Адриян', 'Юрку', 'Адриян', 'Адрияна', 'Адрияну', 'Адриян', 'Адриян', 'Юрку', 'Адрияну', 'Адриян', 'Адрияну', 'Адрияну', 'Адриян', 'Адрияну', 'Петра', 'Адриян', 'Петр', 'Адрияну', 'Адриян', 'Адриян', 'Аксинья', 'Дуня', 'Дуня', 'Дуне', 'Дуня', 'Дуня', 'Самсон', 'Вырин', 'Дуня', 'Дуню', 'Дуня', 'Дуня', 'Дуни', 'шинеле', 'Дуня', 'Дуни', 'Дуня', 'Дуня', 'Дуня', 'Дуня', 'Дуня', 'Дуня', 'Дуне', 'Дуни', 'Дуни', 'Дуня', 'Дуня', 'Дуня', 'мыслию', 'Дуню', 'напрасну', 'Дуню', 'Дуню', 'Дуне', 'Дуня-то', 'Авдотья', 'Авдотьи', 'Дуня', 'Дуня', 'Дуню', 'Дуни', 'Дуня', 'Дуне', 'Дуня', 'Ванька', 'Ванька', 'Ивана', 'Григорий', 'Алексей', 'Алексей', 'Алексей', 'Жан-Поля', 'Алексей', 'Лиза', 'Бетси', 'Григорий', 'Алексея', 'сурмила', 'Памелу', 'Лизою', 'Настя', 'Лиза', 'Настя', 'Настя', 'Лиза', 'Настя', 'Настя', 'Алексея', 'Настя', 'Лиза', 'Настя', 'Лизавета', 'Анисья', 'Ненила', 'Настя', 'Настя', 'Таню', 'Пашу', 'Лиза', 'верьхом', 'Настя', 'Настя', 'Настя', 'Лиза', 'Насти', 'Лиза', 'мила', 'Насти', 'Настя', 'Лизиной', 'Трофиму', 'Лиза', 'Настя', 'Трофим', 'Настей', 'Лиза', 'Лизы', 'Лиза', 'Алексея', 'Лиза', 'Мало-по-малу', 'Лиза', 'Лизе', 'Лиза', 'Алексей', 'Лиза', 'Лиза', 'Алексей', 'Алексею', 'Лиза', 'Лиза', 'Алексею', 'Лиза', 'Алексея', 'Алексей', 'Лиза', 'Лиза', 'Алексей', 'Лиза', 'Акулина', 'Лиза', 'Василий', 'Акулина', 'Лиза', 'Настя', 'Лиза', 'Алексей', 'Лизу', 'Алексей', 'Алексей', 'Лиза', 'Алексея', 'Лиза', 'Алексей', 'Лиза', 'Лиза', 'Алексей', 'Алексей', 'Алексей', 'Лиза', 'Алексей', 'Лиза', 'Иван', 'Григорий', 'верьхом', 'Григорий', 'Иван', 'верьхом', 'Алексеем', 'Лиза', 'Григорий', 'Лиза', 'Григорий', 'Григорий', 'Лизавета', 'Настю', 'Алексей', 'Лизе', 'Григорий', 'Лиза', 'Григорий', 'Лиза', 'верьхом', 'Алексей', 'Лизы', 'Лизы', 'Лиза', 'Лиза', 'Лиза', 'Людовика', 'Алексей', 'Григорий', 'белилы', 'Алексей', 'Лиза', 'Иван', 'Григорий', 'Лизу', 'Белилы', 'Лиза', 'Лизе', 'Лиза', 'Лизу', 'Лиза', 'Лиза', 'Алексею', 'Алексей', 'Лиза', 'Алексей', 'Алексей', 'Лиза', 'Алексей', 'Лиза', 'Алексей', 'Акулин ...
# Часто встречаемые слова без имен собственных: ['.', 'Петровича', 'Белкина', ',', 'мой', 'батюшка', 'он', 'еще', 'к', 'по', 'мне', 'об', 'мы', 'хотя', 'и', 'тем', 'сего', 'было', ';', 'но', 'ей', 'нам', 'о', 'нем', 'ибо', 'вовсе', 'не', 'был', 'Она', 'Мы', 'на', 'письмо', 'его', 'как', 'а', 'вместе', 'с', 'весьма', '*', '!', 'ваше', 'от', 'месяца', 'имел', 'я', 'же', 'в', 'вы', 'свое', 'времени', 'смерти', 'также', 'моего', 'друга', 'соседа', 'С', 'вам', 'всь', 'что', 'из', 'моих', 'Петрович', 'родителей', 'году', 'отец', 'Иванович', 'Он', 'человек', 'их', 'кажется', 'В', '(', ')', 'до', 'самого', 'года', 'почти', 'время', 'село', 'свою', 'своей', 'были', 'никогда', 'она', 'всем', 'была', 'ее', 'того', 'им', 'тут', 'первый', 'год', 'себе', 'более', 'двух', 'тому', 'свои', 'однажды', 'нему', 'книги', 'стал', 'за', 'мною', 'со', 'два', 'то', 'меня', 'ту', 'самую', 'минуту', 'своем', 'тех', 'пор', 'сам', 'да', 'молодого', 'человека', 'столь', 'ко', 'самой', 'каждый', 'день', 'ни', 'образом', 'большею', 'частию', 'друг', 'может', 'которые', 'у', 'все', 'которого', 'Они', 'Однако', 'ж', 'них', 'нашего', 'моя', 'смотря', 'церкви', 'глаза', 'Вот', 'мог', 'жизни', 'Но', 'случае', 'если', 'ничего', 'самом', 'деле', 'над', 'или', 'для', ':', 'Смотритель', 'ему', 'Гробовщик', 'Я', 'ним', 'выстрел', 'вечером', 'одного', 'дома', 'где', 'своих', 'только', 'около', 'лет', 'перед', 'нами', 'наши', 'даже', 'знал', 'пешком', 'стол', 'всех', 'при', 'том', 'У', 'него', 'назад', 'бедной', 'б', 'полку', 'между', 'так', 'На', 'ли', 'отвечал', 'вопросы', 'голову', 'люди', 'нас', 'есть', 'очень', 'после', 'наконец', 'велел', 'тотчас', 'уж', 'это', 'взял', 'своему', 'продолжал', 'казалось', 'снова', 'себя', 'стола', 'который', 'успел', 'сказал', '``', 'случилось', 'доме', "''", 'уже', 'вышел', 'будет', 'угодно', 'несколько', 'минут', 'один', 'другой', 'явился', 'тот', 'Это', 'дворе', 'слова', 'три', '?', 'чрезвычайно', 'во', 'всего', 'мало', 'воображение', 'прежде', 'крайней', 'мере', 'говорил', 'мысль', 'эта', 'заметил', 'кто', 'видом', 'отобедать', 'раз', 'вас', 'непременно', 'словом', 'сторону', 'Всь', 'сели', 'скоро', 'поминутно', 'изо', 'поздно', 'При', 'руку', 'быть', 'хотел', 'Вы', 'бы', 'остановился', 'мою', 'моей', 'Так', 'мое', 'сильно', 'спросил', 'вот', 'вынул', 'молодой', 'всегда', 'Наконец', 'дал', 'тремя', 'увидел', 'должно', 'стрелять', 'руки', '...', 'под', 'Что', 'подумал', 'когда', 'ею', 'пистолет', '-', 'теперь', 'прошло', 'чтоб', 'думал', 'час', 'должна', 'некогда', 'сих', 'вперед', 'вошел', 'лошади', 'могла', 'нее', 'графиня', 'своего', 'там', 'деревню', 'они', 'отправился', 'пошел', 'давно', 'собою', 'Граф', 'начал', 'вдруг', 'чем', 'без', 'Между', 'ней', 'Да', 'А', 'хорошо', 'сказала', 'ты', 'граф', 'сиятельство', 'знаю', 'тебя', 'брат', 'Нет', 'этим', 'правда', 'Как', 'пять', 'стало', 'Не', 'нет', 'Ах', '....', 'здесь', 'этой', 'лошадь', 'домой', 'поехал', 'дело', 'эту', 'комнату', 'подошел', 'Ты', 'узнал', 'закричал', 'приехал', 'просил', 'опять', 'которой', 'каким', 'лицо', 'Вдруг', 'разве', 'тебе', 'сей', 'довольно', 'крыльцо', 'Гавриловна', 'дочери', 'всякой', 'роще', 'таким', 'свидания', 'долго', 'сад', 'через', 'сани', 'ехать', 'своим', 'ними', 'нею', 'сердце', 'вышла', 'будто', 'сын', 'часа', 'поле', 'такая', 'дорогу', 'ехал', 'старик', 'те', 'сем', 'лошадей', 'хоть', 'здоровье', 'барышня', 'дверь', 'отвечала', 'две', 'дочь', 'И', 'Кто', '..', 'Бурмин', 'которая', 'можно', 'милая', 'смотритель', 'станции', 'гробовщик', 'старый', 'Из', 'однако', 'гости', 'совсем', 'вспомнил', 'К', 'Ну', 'смотрителя', 'старого', 'барин', 'такой', 'Минский', 'барыня', 'Берестова', 'Муромский', 'Берестов', 'мисс', 'Жаксон']

# %%
import nltk
import pymorphy2
import pandas as pd

# Убедитесь, что необходимые ресурсы NLTK загружены
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_ru')

# Открытие файла и чтение текста
with open('/home/jovyan/work/ipynb_dock/data/belkin.txt', "r", encoding="utf-8") as f:
    text = f.read()

# Токенизация текста
tokens = nltk.word_tokenize(text)

# Инициализация морфологического анализатора
morph = pymorphy2.MorphAnalyzer()

# Функция для проверки, является ли слово именем собственным
def is_proper_noun(word):
    parsed_word = morph.parse(word)[0]
    return 'Name' in parsed_word.tag

# Извлечение имен собственных
proper_nouns = [word for word in tokens if is_proper_noun(word)]

# Создание списка часто встречаемых слов
freq_dist = nltk.FreqDist(tokens)
common_words = [word for word, freq in freq_dist.items() if freq > 5]

# Удаление имен собственных из списка часто встречаемых слов
common_words_without_proper_nouns = [word for word in common_words if not is_proper_noun(word)]

# Выровнять длину списков, добавив None
max_len = max(len(proper_nouns), len(common_words_without_proper_nouns))
proper_nouns.extend([None] * (max_len - len(proper_nouns)))
common_words_without_proper_nouns.extend([None] * (max_len - len(common_words_without_proper_nouns)))

# Создание DataFrame из списков proper_nouns и common_words_without_proper_nouns
df = pd.DataFrame({
    'proper_nouns': proper_nouns,
    'common_words_without_proper_nouns': common_words_without_proper_nouns
})

# Печать результата
df.sample(10)
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_ru is already up-to-
# [nltk_data]       date!
#     proper_nouns common_words_without_proper_nouns
# 263        Бетси                               мою
# 290        Настя                              чтоб
# 202      Адрияну                            своему
# 64       Сильвио                              отец
# 318         Лиза                                 А
# 438      Алексей                              None
# 186       Адриян                                На
# 139    Владимира                            церкви
# 327         Лиза                               Нет
# 129         Маша                                 у

# %%
import shutil

# Определите пути к исходной и целевой папкам
src = '/opt/conda/lib/python3.11/site-packages/pymorphy2'
dst = '/home/jovyan/backup_pymorphy2_copy'

# Копирование папки
shutil.copytree(src, dst)
# Out:
# '/home/jovyan/backup_pymorphy2_copy'

# %%
import shutil

# Копируем файл в директорию, доступную для скачивания
shutil.copy('/home/jovyan/backup_pymorphy2.tar.gz', '/home/jovyan/work/backup_pymorphy2.tar.gz')
# Out:
# '/home/jovyan/work/backup_pymorphy2.tar.gz'

# %%
# !tar -czvf ~/backup_pymorphy2.tar.gz -C /opt/conda/lib/python3.11/site-packages pymorphy2
# Out:
# pymorphy2/
# pymorphy2/tokenizers.py
# pymorphy2/cache.py
# pymorphy2/lang/
# pymorphy2/lang/ru/
# pymorphy2/lang/ru/__pycache__/
# pymorphy2/lang/ru/__pycache__/__init__.cpython-311.pyc
# pymorphy2/lang/ru/__pycache__/config.cpython-311.pyc
# pymorphy2/lang/ru/config.py
# pymorphy2/lang/ru/__init__.py
# pymorphy2/lang/__pycache__/
# pymorphy2/lang/__pycache__/__init__.cpython-311.pyc
# pymorphy2/lang/uk/
# pymorphy2/lang/uk/_prefixes.py
# pymorphy2/lang/uk/__pycache__/
# pymorphy2/lang/uk/__pycache__/__init__.cpython-311.pyc
# pymorphy2/lang/uk/__pycache__/config.cpython-311.pyc
# pymorphy2/lang/uk/__pycache__/_prefixes.cpython-311.pyc
# pymorphy2/lang/uk/config.py
# pymorphy2/lang/uk/__init__.py
# pymorphy2/lang/__init__.py
# pymorphy2/analyzer.py
# pymorphy2/cli.py
# pymorphy2/__pycache__/
# pymorphy2/__pycache__/__init__.cpython-311.pyc
# pymorphy2/__pycache__/cli.cpython-311.pyc
# pymorphy2/__pycache__/tagset.cpython-311.pyc
# pymorphy2/__pycache__/tokenizers.cpython-311.pyc
# pymorphy2/__pycache__/version.cpython-311.pyc
# pymorphy2/__pycache__/utils.cpython-311.pyc
# pymorphy2/__pycache__/cache.cpython-311.pyc
# pymorphy2/__pycache__/analyzer.cpython-311.pyc
# pymorphy2/__pycache__/dawg.cpython-311.pyc
# pymorphy2/__pycache__/shapes.cpython-311.pyc
# pymorphy2/version.py
# pymorphy2/shapes.py
# pymorphy2/opencorpora_dict/
# pymorphy2/opencorpora_dict/storage.py
# pymorphy2/opencorpora_dict/probability.py
# pymorphy2/opencorpora_dict/__pycache__/
# pymorphy2/opencorpora_dict/__pycache__/__init__.cpython-311.pyc
# pymorphy2/opencorpora_dict/__pycache__/storage.cpython-311.pyc
# pymorphy2/opencorpora_dict/__pycache__/wrapper.cpython-311.pyc
# pymorphy2/opencorpora_dict/__pycache__/parse.cpython-311.pyc
# pymorphy2/opencorpora_dict/__pycache__/compile.cpython-311.pyc
# pymorphy2/opencorpora_dict/__pycache__/probability.cpython-311.pyc
# pymorphy2/opencorpora_dict/__pycache__/preprocess.cpython-311.pyc
# pymorphy2/opencorpora_dict/wrapper.py
# pymorphy2/opencorpora_dict/preprocess.py
# pymorphy2/opencorpora_dict/compile.py
# pymorphy2/opencorpora_dict/__init__.py
# pymorphy2/opencorpora_dict/parse.py
# pymorphy2/__init__.py
# pymorphy2/tagset.py
# pymorphy2/dawg.py
# pymorphy2/utils.py
# pymorphy2/units/
# pymorphy2/units/base.py
# pymorphy2/units/by_shape.py
# pymorphy2/units/by_hyphen.py
# pymorphy2/units/__pycache__/
# pymorphy2/units/__pycache__/__init__.cpython-311.pyc
# pymorphy2/units/__pycache__/by_analogy.cpython-311.pyc
# pymorphy2/units/__pycache__/by_shape.cpython-311.pyc
# pymorphy2/units/__pycache__/by_lookup.cpython-311.pyc
# pymorphy2/units/__pycache__/unkn.cpython-311.pyc
# pymorphy2/units/__pycache__/utils.cpython-311.pyc
# pymorphy2/units/__pycache__/by_hyphen.cpython-311.pyc
# pymorphy2/units/__pycache__/abbreviations.cpython-311.pyc
# pymorphy2/units/__pycache__/base.cpython-311.pyc
# pymorphy2/units/by_lookup.py
# pymorphy2/units/by_analogy.py
# pymorphy2/units/__init__.py
# pymorphy2/units/utils.py
# pymorphy2/units/unkn.py
# pymorphy2/units/abbreviations.py

# %%
# !pip install pymorphy2
# Out:
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting dawg-python>=0.7.1 (from pymorphy2)
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl.metadata (7.0 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4 (from pymorphy2)
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting docopt>=0.6 (from pymorphy2)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 492.0 kB/s eta 0:00:000:00:01
# Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 21.9 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=96732e4fffafae9c2d03c8b409d4dd8883b1642771e429d3a4bb960c20a186c4
#   Stored in directory: /home/jovyan/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built docopt
# Installing collected packages: pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844

# %%
# !pip install --upgrade pymorphy2
# Out:
# Requirement already satisfied: pymorphy2 in /opt/conda/lib/python3.11/site-packages (0.9.1)
# Requirement already satisfied: dawg-python>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from pymorphy2) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /opt/conda/lib/python3.11/site-packages (from pymorphy2) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in /opt/conda/lib/python3.11/site-packages (from pymorphy2) (0.6.2)

# %%
# !pip install --upgrade nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.11/site-packages (3.9.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.11/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.11/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from nltk) (4.66.1)

# %%
# !pip show pymorphy2
# Out:
# Name: pymorphy2
# Version: 0.9.1
# Summary: Morphological analyzer (POS tagger + inflection engine) for Russian language.
# Home-page: https://github.com/kmike/pymorphy2/
# Author: Mikhail Korobov
# Author-email: kmike84@gmail.com
# License: MIT license
# Location: /opt/conda/lib/python3.11/site-packages
# Requires: dawg-python, docopt, pymorphy2-dicts-ru
# Required-by:

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

with open('/home/jovyan/work/ipynb_dock/data/belkin.txt',  encoding='utf-8') as f:
    ls = []
    for line in f:
        lst = line.split()

        words = []
        for word in lst:
            p = morph.parse(word)[0]  # делаем разбор
            words.append(p.normal_form)

        ls.append(words)

len(ls)
# Out:
# 312

# %%
# Если len(ls) выводит 312, это означает, что файл belkin.txt содержит 312 строк. len(ls) не считает слова, а считает количество списков (строк) в ls.

# Если вы хотите подсчитать количество слов
# Если ваша цель — подсчитать количество слов в файле, вам нужно изменить код, чтобы он считал слова, а не строки:

# %%
with open('/home/jovyan/work/ipynb_dock/data/belkin.txt',  encoding='utf-8') as f:
    word_count = 0
    for line in f:
        lst = line.split()

        words = []
        for word in lst:
            p = morph.parse(word)[0]
            words.append(p.normal_form)

        word_count += len(words)

print(word_count)  # Печатает количество слов
# Out:
# 19212

# %%
import nltk
import pymorphy2

# Убедитесь, что необходимые ресурсы NLTK загружены
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_ru')

# Открываем файл и читаем текст
with open('/home/jovyan/work/ipynb_dock/data/belkin.txt', "r", encoding="utf-8") as f:
    text = f.read()

# Токенизация текста
tokens = nltk.word_tokenize(text)

# Инициализация морфологического анализатора
morph = pymorphy2.MorphAnalyzer()

# Функция для проверки, является ли слово именем собственным
def is_proper_noun(word):
    parsed_word = morph.parse(word)[0]
    return 'Name' in parsed_word.tag

# Извлечение имен собственных
proper_nouns = [word for word in tokens if is_proper_noun(word)]

# Создание списка часто встречаемых слов
freq_dist = nltk.FreqDist(tokens)
common_words = [word for word, freq in freq_dist.items() if freq > 5]

# Удаление имен собственных из списка часто встречаемых слов
common_words_without_proper_nouns = [word for word in common_words if not is_proper_noun(word)]

# Печать результатов
print("Имена собственные:", proper_nouns)
print("Часто встречаемые слова без имен собственных:", common_words_without_proper_nouns)
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_ru is already up-to-
# [nltk_data]       date!
# Имена собственные: ['Александр', 'Ивана', 'Митрофан', 'Марье', 'Трафилиной', 'Ивана', 'Ивану', 'Ивана', 'Иван', 'Петр', 'Пелагее', 'Иван', 'Иван', 'Ивана', 'Ивана', 'Иван', 'Ивана', 'Ивана', 'Иван', 'Иван', 'Иван', 'Иван', 'Иван', 'Иван', 'Ивана', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'мел', 'Сильвио', 'Сильвио', 'мел', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Денисом', 'Сильвио', 'Сильвио', 'Сильвио', 'пол', 'Сильвио', 'пол', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'верьхом', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Маша', 'Маше', 'Сильвио', 'Сильвио', 'Маша', 'Маша', 'Сильвио', 'Сильвио', 'Александра', 'Ипсиланти', 'Скулянами', 'валит', 'Гаврила', 'Марья', 'едине', 'Марьи', 'Владимир', 'Марья', 'Владимир', 'Марья', 'Владимира', 'Маша', 'Маша', 'Маша', 'Владимира', 'Владимир', 'Дравин', 'Владимира', 'Владимира', 'Владимир', 'Марья', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Жадрина', 'Владимир', 'Владимира', 'Мало-по-малу', 'Владимир', 'Жадрина', 'Владимир', 'Владимир', 'Владимир', 'Жадрина', 'Владимир', 'Владимир', 'Владимир', 'Жадрина', 'Владимир', 'Гаврила', 'Прасковья', 'Гаврила', 'Марьи', 'Марья', 'Маша', 'Гаврила', 'Маша', 'Маша', 'Прасковья', 'Маша', 'Маша', 'Марья', 'Владимира', 'Марьи', 'Владимира', 'Гаврилы', 'Владимир', 'Маше', 'Владимире', 'Гаврила', 'Прасковьи', 'Марья', 'Владимир', 'Маши', 'Артемизы', 'Марья', 'Марья', 'Георгием', 'Марьи', 'Марья', 'Марьей', 'Марьи', 'любовию', 'Марье', 'Прасковья', 'Марье', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'пологал', 'Марья', 'Адрияна', 'Адриян', 'Вальтер', 'Скотт', 'Адриян', 'Адриян', 'Готлиб', 'Готлиба', 'Адриян', 'Адриян', 'Адрияна', 'Дарьи', 'Адриян', 'Лотхен', 'Адриян', 'Луизы', 'Луизы', 'Адриян', 'Юрку', 'Адриян', 'Адрияна', 'Адрияну', 'Адриян', 'Адриян', 'Юрку', 'Адрияну', 'Адриян', 'Адрияну', 'Адрияну', 'Адриян', 'Адрияну', 'Петра', 'Адриян', 'Петр', 'Адрияну', 'Адриян', 'Адриян', 'Аксинья', 'Дуня', 'Дуня', 'Дуне', 'Дуня', 'Дуня', 'Самсон', 'Вырин', 'Дуня', 'Дуню', 'Дуня', 'Дуня', 'Дуни', 'шинеле', 'Дуня', 'Дуни', 'Дуня', 'Дуня', 'Дуня', 'Дуня', 'Дуня', 'Дуня', 'Дуне', 'Дуни', 'Дуни', 'Дуня', 'Дуня', 'Дуня', 'мыслию', 'Дуню', 'напрасну', 'Дуню', 'Дуню', 'Дуне', 'Дуня-то', 'Авдотья', 'Авдотьи', 'Дуня', 'Дуня', 'Дуню', 'Дуни', 'Дуня', 'Дуне', 'Дуня', 'Ванька', 'Ванька', 'Ивана', 'Григорий', 'Алексей', 'Алексей', 'Алексей', 'Жан-Поля', 'Алексей', 'Лиза', 'Бетси', 'Григорий', 'Алексея', 'сурмила', 'Памелу', 'Лизою', 'Настя', 'Лиза', 'Настя', 'Настя', 'Лиза', 'Настя', 'Настя', 'Алексея', 'Настя', 'Лиза', 'Настя', 'Лизавета', 'Анисья', 'Ненила', 'Настя', 'Настя', 'Таню', 'Пашу', 'Лиза', 'верьхом', 'Настя', 'Настя', 'Настя', 'Лиза', 'Насти', 'Лиза', 'мила', 'Насти', 'Настя', 'Лизиной', 'Трофиму', 'Лиза', 'Настя', 'Трофим', 'Настей', 'Лиза', 'Лизы', 'Лиза', 'Алексея', 'Лиза', 'Мало-по-малу', 'Лиза', 'Лизе', 'Лиза', 'Алексей', 'Лиза', 'Лиза', 'Алексей', 'Алексею', 'Лиза', 'Лиза', 'Алексею', 'Лиза', 'Алексея', 'Алексей', 'Лиза', 'Лиза', 'Алексей', 'Лиза', 'Акулина', 'Лиза', 'Василий', 'Акулина', 'Лиза', 'Настя', 'Лиза', 'Алексей', 'Лизу', 'Алексей', 'Алексей', 'Лиза', 'Алексея', 'Лиза', 'Алексей', 'Лиза', 'Лиза', 'Алексей', 'Алексей', 'Алексей', 'Лиза', 'Алексей', 'Лиза', 'Иван', 'Григорий', 'верьхом', 'Григорий', 'Иван', 'верьхом', 'Алексеем', 'Лиза', 'Григорий', 'Лиза', 'Григорий', 'Григорий', 'Лизавета', 'Настю', 'Алексей', 'Лизе', 'Григорий', 'Лиза', 'Григорий', 'Лиза', 'верьхом', 'Алексей', 'Лизы', 'Лизы', 'Лиза', 'Лиза', 'Лиза', 'Людовика', 'Алексей', 'Григорий', 'белилы', 'Алексей', 'Лиза', 'Иван', 'Григорий', 'Лизу', 'Белилы', 'Лиза', 'Лизе', 'Лиза', 'Лизу', 'Лиза', 'Лиза', 'Алексею', 'Алексей', 'Лиза', 'Алексей', 'Алексей', 'Лиза', 'Алексей', 'Лиза', 'Алексей', 'Акулин ...
# Часто встречаемые слова без имен собственных: ['.', 'Петровича', 'Белкина', ',', 'мой', 'батюшка', 'он', 'еще', 'к', 'по', 'мне', 'об', 'мы', 'хотя', 'и', 'тем', 'сего', 'было', ';', 'но', 'ей', 'нам', 'о', 'нем', 'ибо', 'вовсе', 'не', 'был', 'Она', 'Мы', 'на', 'письмо', 'его', 'как', 'а', 'вместе', 'с', 'весьма', '*', '!', 'ваше', 'от', 'месяца', 'имел', 'я', 'же', 'в', 'вы', 'свое', 'времени', 'смерти', 'также', 'моего', 'друга', 'соседа', 'С', 'вам', 'всь', 'что', 'из', 'моих', 'Петрович', 'родителей', 'году', 'отец', 'Иванович', 'Он', 'человек', 'их', 'кажется', 'В', '(', ')', 'до', 'самого', 'года', 'почти', 'время', 'село', 'свою', 'своей', 'были', 'никогда', 'она', 'всем', 'была', 'ее', 'того', 'им', 'тут', 'первый', 'год', 'себе', 'более', 'двух', 'тому', 'свои', 'однажды', 'нему', 'книги', 'стал', 'за', 'мною', 'со', 'два', 'то', 'меня', 'ту', 'самую', 'минуту', 'своем', 'тех', 'пор', 'сам', 'да', 'молодого', 'человека', 'столь', 'ко', 'самой', 'каждый', 'день', 'ни', 'образом', 'большею', 'частию', 'друг', 'может', 'которые', 'у', 'все', 'которого', 'Они', 'Однако', 'ж', 'них', 'нашего', 'моя', 'смотря', 'церкви', 'глаза', 'Вот', 'мог', 'жизни', 'Но', 'случае', 'если', 'ничего', 'самом', 'деле', 'над', 'или', 'для', ':', 'Смотритель', 'ему', 'Гробовщик', 'Я', 'ним', 'выстрел', 'вечером', 'одного', 'дома', 'где', 'своих', 'только', 'около', 'лет', 'перед', 'нами', 'наши', 'даже', 'знал', 'пешком', 'стол', 'всех', 'при', 'том', 'У', 'него', 'назад', 'бедной', 'б', 'полку', 'между', 'так', 'На', 'ли', 'отвечал', 'вопросы', 'голову', 'люди', 'нас', 'есть', 'очень', 'после', 'наконец', 'велел', 'тотчас', 'уж', 'это', 'взял', 'своему', 'продолжал', 'казалось', 'снова', 'себя', 'стола', 'который', 'успел', 'сказал', '``', 'случилось', 'доме', "''", 'уже', 'вышел', 'будет', 'угодно', 'несколько', 'минут', 'один', 'другой', 'явился', 'тот', 'Это', 'дворе', 'слова', 'три', '?', 'чрезвычайно', 'во', 'всего', 'мало', 'воображение', 'прежде', 'крайней', 'мере', 'говорил', 'мысль', 'эта', 'заметил', 'кто', 'видом', 'отобедать', 'раз', 'вас', 'непременно', 'словом', 'сторону', 'Всь', 'сели', 'скоро', 'поминутно', 'изо', 'поздно', 'При', 'руку', 'быть', 'хотел', 'Вы', 'бы', 'остановился', 'мою', 'моей', 'Так', 'мое', 'сильно', 'спросил', 'вот', 'вынул', 'молодой', 'всегда', 'Наконец', 'дал', 'тремя', 'увидел', 'должно', 'стрелять', 'руки', '...', 'под', 'Что', 'подумал', 'когда', 'ею', 'пистолет', '-', 'теперь', 'прошло', 'чтоб', 'думал', 'час', 'должна', 'некогда', 'сих', 'вперед', 'вошел', 'лошади', 'могла', 'нее', 'графиня', 'своего', 'там', 'деревню', 'они', 'отправился', 'пошел', 'давно', 'собою', 'Граф', 'начал', 'вдруг', 'чем', 'без', 'Между', 'ней', 'Да', 'А', 'хорошо', 'сказала', 'ты', 'граф', 'сиятельство', 'знаю', 'тебя', 'брат', 'Нет', 'этим', 'правда', 'Как', 'пять', 'стало', 'Не', 'нет', 'Ах', '....', 'здесь', 'этой', 'лошадь', 'домой', 'поехал', 'дело', 'эту', 'комнату', 'подошел', 'Ты', 'узнал', 'закричал', 'приехал', 'просил', 'опять', 'которой', 'каким', 'лицо', 'Вдруг', 'разве', 'тебе', 'сей', 'довольно', 'крыльцо', 'Гавриловна', 'дочери', 'всякой', 'роще', 'таким', 'свидания', 'долго', 'сад', 'через', 'сани', 'ехать', 'своим', 'ними', 'нею', 'сердце', 'вышла', 'будто', 'сын', 'часа', 'поле', 'такая', 'дорогу', 'ехал', 'старик', 'те', 'сем', 'лошадей', 'хоть', 'здоровье', 'барышня', 'дверь', 'отвечала', 'две', 'дочь', 'И', 'Кто', '..', 'Бурмин', 'которая', 'можно', 'милая', 'смотритель', 'станции', 'гробовщик', 'старый', 'Из', 'однако', 'гости', 'совсем', 'вспомнил', 'К', 'Ну', 'смотрителя', 'старого', 'барин', 'такой', 'Минский', 'барыня', 'Берестова', 'Муромский', 'Берестов', 'мисс', 'Жаксон']

# %%
import nltk
import pymorphy2

# Убедитесь, что необходимые ресурсы NLTK загружены
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_ru')

# Открываем файл и читаем текст
with open('/home/jovyan/work/ipynb_dock/data/belkin.txt', "r", encoding="utf-8") as f:
    text = f.read()

# Токенизация текста
tokens = nltk.word_tokenize(text)

# Инициализация морфологического анализатора
morph = pymorphy2.MorphAnalyzer()

# Функция для проверки, является ли слово именем собственным
def is_proper_noun(word):
    parsed_word = morph.parse(word)[0]
    return 'Name' in parsed_word.tag

# Извлечение имен собственных
proper_nouns = [word for word in tokens if is_proper_noun(word)]

# Создание списка часто встречаемых слов
freq_dist = nltk.FreqDist(tokens)
common_words = [word for word, freq in freq_dist.items() if freq > 5]

# Удаление имен собственных из списка часто встречаемых слов
common_words_without_proper_nouns = [word for word in common_words if not is_proper_noun(word)]

# Печать результатов
print("Имена собственные:", proper_nouns)
print("Часто встречаемые слова без имен собственных:", common_words_without_proper_nouns)
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_ru is already up-to-
# [nltk_data]       date!
# Имена собственные: ['Александр', 'Ивана', 'Митрофан', 'Марье', 'Трафилиной', 'Ивана', 'Ивану', 'Ивана', 'Иван', 'Петр', 'Пелагее', 'Иван', 'Иван', 'Ивана', 'Ивана', 'Иван', 'Ивана', 'Ивана', 'Иван', 'Иван', 'Иван', 'Иван', 'Иван', 'Иван', 'Ивана', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'мел', 'Сильвио', 'Сильвио', 'мел', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Денисом', 'Сильвио', 'Сильвио', 'Сильвио', 'пол', 'Сильвио', 'пол', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'верьхом', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Маша', 'Маше', 'Сильвио', 'Сильвио', 'Маша', 'Маша', 'Сильвио', 'Сильвио', 'Александра', 'Ипсиланти', 'Скулянами', 'валит', 'Гаврила', 'Марья', 'едине', 'Марьи', 'Владимир', 'Марья', 'Владимир', 'Марья', 'Владимира', 'Маша', 'Маша', 'Маша', 'Владимира', 'Владимир', 'Дравин', 'Владимира', 'Владимира', 'Владимир', 'Марья', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Жадрина', 'Владимир', 'Владимира', 'Мало-по-малу', 'Владимир', 'Жадрина', 'Владимир', 'Владимир', 'Владимир', 'Жадрина', 'Владимир', 'Владимир', 'Владимир', 'Жадрина', 'Владимир', 'Гаврила', 'Прасковья', 'Гаврила', 'Марьи', 'Марья', 'Маша', 'Гаврила', 'Маша', 'Маша', 'Прасковья', 'Маша', 'Маша', 'Марья', 'Владимира', 'Марьи', 'Владимира', 'Гаврилы', 'Владимир', 'Маше', 'Владимире', 'Гаврила', 'Прасковьи', 'Марья', 'Владимир', 'Маши', 'Артемизы', 'Марья', 'Марья', 'Георгием', 'Марьи', 'Марья', 'Марьей', 'Марьи', 'любовию', 'Марье', 'Прасковья', 'Марье', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'пологал', 'Марья', 'Адрияна', 'Адриян', 'Вальтер', 'Скотт', 'Адриян', 'Адриян', 'Готлиб', 'Готлиба', 'Адриян', 'Адриян', 'Адрияна', 'Дарьи', 'Адриян', 'Лотхен', 'Адриян', 'Луизы', 'Луизы', 'Адриян', 'Юрку', 'Адриян', 'Адрияна', 'Адрияну', 'Адриян', 'Адриян', 'Юрку', 'Адрияну', 'Адриян', 'Адрияну', 'Адрияну', 'Адриян', 'Адрияну', 'Петра', 'Адриян', 'Петр', 'Адрияну', 'Адриян', 'Адриян', 'Аксинья', 'Дуня', 'Дуня', 'Дуне', 'Дуня', 'Дуня', 'Самсон', 'Вырин', 'Дуня', 'Дуню', 'Дуня', 'Дуня', 'Дуни', 'шинеле', 'Дуня', 'Дуни', 'Дуня', 'Дуня', 'Дуня', 'Дуня', 'Дуня', 'Дуня', 'Дуне', 'Дуни', 'Дуни', 'Дуня', 'Дуня', 'Дуня', 'мыслию', 'Дуню', 'напрасну', 'Дуню', 'Дуню', 'Дуне', 'Дуня-то', 'Авдотья', 'Авдотьи', 'Дуня', 'Дуня', 'Дуню', 'Дуни', 'Дуня', 'Дуне', 'Дуня', 'Ванька', 'Ванька', 'Ивана', 'Григорий', 'Алексей', 'Алексей', 'Алексей', 'Жан-Поля', 'Алексей', 'Лиза', 'Бетси', 'Григорий', 'Алексея', 'сурмила', 'Памелу', 'Лизою', 'Настя', 'Лиза', 'Настя', 'Настя', 'Лиза', 'Настя', 'Настя', 'Алексея', 'Настя', 'Лиза', 'Настя', 'Лизавета', 'Анисья', 'Ненила', 'Настя', 'Настя', 'Таню', 'Пашу', 'Лиза', 'верьхом', 'Настя', 'Настя', 'Настя', 'Лиза', 'Насти', 'Лиза', 'мила', 'Насти', 'Настя', 'Лизиной', 'Трофиму', 'Лиза', 'Настя', 'Трофим', 'Настей', 'Лиза', 'Лизы', 'Лиза', 'Алексея', 'Лиза', 'Мало-по-малу', 'Лиза', 'Лизе', 'Лиза', 'Алексей', 'Лиза', 'Лиза', 'Алексей', 'Алексею', 'Лиза', 'Лиза', 'Алексею', 'Лиза', 'Алексея', 'Алексей', 'Лиза', 'Лиза', 'Алексей', 'Лиза', 'Акулина', 'Лиза', 'Василий', 'Акулина', 'Лиза', 'Настя', 'Лиза', 'Алексей', 'Лизу', 'Алексей', 'Алексей', 'Лиза', 'Алексея', 'Лиза', 'Алексей', 'Лиза', 'Лиза', 'Алексей', 'Алексей', 'Алексей', 'Лиза', 'Алексей', 'Лиза', 'Иван', 'Григорий', 'верьхом', 'Григорий', 'Иван', 'верьхом', 'Алексеем', 'Лиза', 'Григорий', 'Лиза', 'Григорий', 'Григорий', 'Лизавета', 'Настю', 'Алексей', 'Лизе', 'Григорий', 'Лиза', 'Григорий', 'Лиза', 'верьхом', 'Алексей', 'Лизы', 'Лизы', 'Лиза', 'Лиза', 'Лиза', 'Людовика', 'Алексей', 'Григорий', 'белилы', 'Алексей', 'Лиза', 'Иван', 'Григорий', 'Лизу', 'Белилы', 'Лиза', 'Лизе', 'Лиза', 'Лизу', 'Лиза', 'Лиза', 'Алексею', 'Алексей', 'Лиза', 'Алексей', 'Алексей', 'Лиза', 'Алексей', 'Лиза', 'Алексей', 'Акулин ...
# Часто встречаемые слова без имен собственных: ['.', 'Петровича', 'Белкина', ',', 'мой', 'батюшка', 'он', 'еще', 'к', 'по', 'мне', 'об', 'мы', 'хотя', 'и', 'тем', 'сего', 'было', ';', 'но', 'ей', 'нам', 'о', 'нем', 'ибо', 'вовсе', 'не', 'был', 'Она', 'Мы', 'на', 'письмо', 'его', 'как', 'а', 'вместе', 'с', 'весьма', '*', '!', 'ваше', 'от', 'месяца', 'имел', 'я', 'же', 'в', 'вы', 'свое', 'времени', 'смерти', 'также', 'моего', 'друга', 'соседа', 'С', 'вам', 'всь', 'что', 'из', 'моих', 'Петрович', 'родителей', 'году', 'отец', 'Иванович', 'Он', 'человек', 'их', 'кажется', 'В', '(', ')', 'до', 'самого', 'года', 'почти', 'время', 'село', 'свою', 'своей', 'были', 'никогда', 'она', 'всем', 'была', 'ее', 'того', 'им', 'тут', 'первый', 'год', 'себе', 'более', 'двух', 'тому', 'свои', 'однажды', 'нему', 'книги', 'стал', 'за', 'мною', 'со', 'два', 'то', 'меня', 'ту', 'самую', 'минуту', 'своем', 'тех', 'пор', 'сам', 'да', 'молодого', 'человека', 'столь', 'ко', 'самой', 'каждый', 'день', 'ни', 'образом', 'большею', 'частию', 'друг', 'может', 'которые', 'у', 'все', 'которого', 'Они', 'Однако', 'ж', 'них', 'нашего', 'моя', 'смотря', 'церкви', 'глаза', 'Вот', 'мог', 'жизни', 'Но', 'случае', 'если', 'ничего', 'самом', 'деле', 'над', 'или', 'для', ':', 'Смотритель', 'ему', 'Гробовщик', 'Я', 'ним', 'выстрел', 'вечером', 'одного', 'дома', 'где', 'своих', 'только', 'около', 'лет', 'перед', 'нами', 'наши', 'даже', 'знал', 'пешком', 'стол', 'всех', 'при', 'том', 'У', 'него', 'назад', 'бедной', 'б', 'полку', 'между', 'так', 'На', 'ли', 'отвечал', 'вопросы', 'голову', 'люди', 'нас', 'есть', 'очень', 'после', 'наконец', 'велел', 'тотчас', 'уж', 'это', 'взял', 'своему', 'продолжал', 'казалось', 'снова', 'себя', 'стола', 'который', 'успел', 'сказал', '``', 'случилось', 'доме', "''", 'уже', 'вышел', 'будет', 'угодно', 'несколько', 'минут', 'один', 'другой', 'явился', 'тот', 'Это', 'дворе', 'слова', 'три', '?', 'чрезвычайно', 'во', 'всего', 'мало', 'воображение', 'прежде', 'крайней', 'мере', 'говорил', 'мысль', 'эта', 'заметил', 'кто', 'видом', 'отобедать', 'раз', 'вас', 'непременно', 'словом', 'сторону', 'Всь', 'сели', 'скоро', 'поминутно', 'изо', 'поздно', 'При', 'руку', 'быть', 'хотел', 'Вы', 'бы', 'остановился', 'мою', 'моей', 'Так', 'мое', 'сильно', 'спросил', 'вот', 'вынул', 'молодой', 'всегда', 'Наконец', 'дал', 'тремя', 'увидел', 'должно', 'стрелять', 'руки', '...', 'под', 'Что', 'подумал', 'когда', 'ею', 'пистолет', '-', 'теперь', 'прошло', 'чтоб', 'думал', 'час', 'должна', 'некогда', 'сих', 'вперед', 'вошел', 'лошади', 'могла', 'нее', 'графиня', 'своего', 'там', 'деревню', 'они', 'отправился', 'пошел', 'давно', 'собою', 'Граф', 'начал', 'вдруг', 'чем', 'без', 'Между', 'ней', 'Да', 'А', 'хорошо', 'сказала', 'ты', 'граф', 'сиятельство', 'знаю', 'тебя', 'брат', 'Нет', 'этим', 'правда', 'Как', 'пять', 'стало', 'Не', 'нет', 'Ах', '....', 'здесь', 'этой', 'лошадь', 'домой', 'поехал', 'дело', 'эту', 'комнату', 'подошел', 'Ты', 'узнал', 'закричал', 'приехал', 'просил', 'опять', 'которой', 'каким', 'лицо', 'Вдруг', 'разве', 'тебе', 'сей', 'довольно', 'крыльцо', 'Гавриловна', 'дочери', 'всякой', 'роще', 'таким', 'свидания', 'долго', 'сад', 'через', 'сани', 'ехать', 'своим', 'ними', 'нею', 'сердце', 'вышла', 'будто', 'сын', 'часа', 'поле', 'такая', 'дорогу', 'ехал', 'старик', 'те', 'сем', 'лошадей', 'хоть', 'здоровье', 'барышня', 'дверь', 'отвечала', 'две', 'дочь', 'И', 'Кто', '..', 'Бурмин', 'которая', 'можно', 'милая', 'смотритель', 'станции', 'гробовщик', 'старый', 'Из', 'однако', 'гости', 'совсем', 'вспомнил', 'К', 'Ну', 'смотрителя', 'старого', 'барин', 'такой', 'Минский', 'барыня', 'Берестова', 'Муромский', 'Берестов', 'мисс', 'Жаксон']

# %%
import inspect

# Пример функции, которую мы хотим проанализировать
class SomeClass:
    def __init__(self, arg1, arg2, kwarg1=None):
        pass

# Получение аргументов функции __init__ класса
fullargspec = inspect.getfullargspec(SomeClass.__init__)
args = fullargspec.args
varargs = fullargspec.varargs
varkw = fullargspec.varkw
defaults = fullargspec.defaults

# Обработка аргументов
args_without_self = sorted(args[1:])

print("Аргументы:", args_without_self)
print("Дополнительные аргументы (varargs):", varargs)
print("Ключевые аргументы (varkw):", varkw)
print("Значения по умолчанию (defaults):", defaults)
# Out:
# Аргументы: ['arg1', 'arg2', 'kwarg1']
# Дополнительные аргументы (varargs): None
# Ключевые аргументы (varkw): None
# Значения по умолчанию (defaults): (None,)

# %%
import nltk
import pymorphy2

# Убедитесь, что необходимые ресурсы NLTK загружены
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_ru')

# Открываем файл и читаем текст
with open('/home/jovyan/work/ipynb_dock/data/belkin.txt', "r", encoding="utf-8") as f:
    text = f.read()

# Токенизация текста
tokens = nltk.word_tokenize(text)

# Инициализация морфологического анализатора
morph = pymorphy2.MorphAnalyzer()

# Функция для проверки, является ли слово именем собственным
def is_proper_noun(word):
    parsed_word = morph.parse(word)[0]
    return 'Name' in parsed_word.tag

# Извлечение имен собственных
proper_nouns = [word for word in tokens if is_proper_noun(word)]

# Создание списка часто встречаемых слов
freq_dist = nltk.FreqDist(tokens)
common_words = [word for word, freq in freq_dist.items() if freq > 5]

# Удаление имен собственных из списка часто встречаемых слов
common_words_without_proper_nouns = [word for word in common_words if not is_proper_noun(word)]

# Печать результатов
print("Имена собственные:", proper_nouns)
print("Часто встречаемые слова без имен собственных:", common_words_without_proper_nouns)
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_ru is already up-to-
# [nltk_data]       date!
# Имена собственные: ['Александр', 'Ивана', 'Митрофан', 'Марье', 'Трафилиной', 'Ивана', 'Ивану', 'Ивана', 'Иван', 'Петр', 'Пелагее', 'Иван', 'Иван', 'Ивана', 'Ивана', 'Иван', 'Ивана', 'Ивана', 'Иван', 'Иван', 'Иван', 'Иван', 'Иван', 'Иван', 'Ивана', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'мел', 'Сильвио', 'Сильвио', 'мел', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Денисом', 'Сильвио', 'Сильвио', 'Сильвио', 'пол', 'Сильвио', 'пол', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'верьхом', 'Сильвио', 'Сильвио', 'Сильвио', 'Сильвио', 'Маша', 'Маше', 'Сильвио', 'Сильвио', 'Маша', 'Маша', 'Сильвио', 'Сильвио', 'Александра', 'Ипсиланти', 'Скулянами', 'валит', 'Гаврила', 'Марья', 'едине', 'Марьи', 'Владимир', 'Марья', 'Владимир', 'Марья', 'Владимира', 'Маша', 'Маша', 'Маша', 'Владимира', 'Владимир', 'Дравин', 'Владимира', 'Владимира', 'Владимир', 'Марья', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Владимир', 'Жадрина', 'Владимир', 'Владимира', 'Мало-по-малу', 'Владимир', 'Жадрина', 'Владимир', 'Владимир', 'Владимир', 'Жадрина', 'Владимир', 'Владимир', 'Владимир', 'Жадрина', 'Владимир', 'Гаврила', 'Прасковья', 'Гаврила', 'Марьи', 'Марья', 'Маша', 'Гаврила', 'Маша', 'Маша', 'Прасковья', 'Маша', 'Маша', 'Марья', 'Владимира', 'Марьи', 'Владимира', 'Гаврилы', 'Владимир', 'Маше', 'Владимире', 'Гаврила', 'Прасковьи', 'Марья', 'Владимир', 'Маши', 'Артемизы', 'Марья', 'Марья', 'Георгием', 'Марьи', 'Марья', 'Марьей', 'Марьи', 'любовию', 'Марье', 'Прасковья', 'Марье', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'Марья', 'пологал', 'Марья', 'Адрияна', 'Адриян', 'Вальтер', 'Скотт', 'Адриян', 'Адриян', 'Готлиб', 'Готлиба', 'Адриян', 'Адриян', 'Адрияна', 'Дарьи', 'Адриян', 'Лотхен', 'Адриян', 'Луизы', 'Луизы', 'Адриян', 'Юрку', 'Адриян', 'Адрияна', 'Адрияну', 'Адриян', 'Адриян', 'Юрку', 'Адрияну', 'Адриян', 'Адрияну', 'Адрияну', 'Адриян', 'Адрияну', 'Петра', 'Адриян', 'Петр', 'Адрияну', 'Адриян', 'Адриян', 'Аксинья', 'Дуня', 'Дуня', 'Дуне', 'Дуня', 'Дуня', 'Самсон', 'Вырин', 'Дуня', 'Дуню', 'Дуня', 'Дуня', 'Дуни', 'шинеле', 'Дуня', 'Дуни', 'Дуня', 'Дуня', 'Дуня', 'Дуня', 'Дуня', 'Дуня', 'Дуне', 'Дуни', 'Дуни', 'Дуня', 'Дуня', 'Дуня', 'мыслию', 'Дуню', 'напрасну', 'Дуню', 'Дуню', 'Дуне', 'Дуня-то', 'Авдотья', 'Авдотьи', 'Дуня', 'Дуня', 'Дуню', 'Дуни', 'Дуня', 'Дуне', 'Дуня', 'Ванька', 'Ванька', 'Ивана', 'Григорий', 'Алексей', 'Алексей', 'Алексей', 'Жан-Поля', 'Алексей', 'Лиза', 'Бетси', 'Григорий', 'Алексея', 'сурмила', 'Памелу', 'Лизою', 'Настя', 'Лиза', 'Настя', 'Настя', 'Лиза', 'Настя', 'Настя', 'Алексея', 'Настя', 'Лиза', 'Настя', 'Лизавета', 'Анисья', 'Ненила', 'Настя', 'Настя', 'Таню', 'Пашу', 'Лиза', 'верьхом', 'Настя', 'Настя', 'Настя', 'Лиза', 'Насти', 'Лиза', 'мила', 'Насти', 'Настя', 'Лизиной', 'Трофиму', 'Лиза', 'Настя', 'Трофим', 'Настей', 'Лиза', 'Лизы', 'Лиза', 'Алексея', 'Лиза', 'Мало-по-малу', 'Лиза', 'Лизе', 'Лиза', 'Алексей', 'Лиза', 'Лиза', 'Алексей', 'Алексею', 'Лиза', 'Лиза', 'Алексею', 'Лиза', 'Алексея', 'Алексей', 'Лиза', 'Лиза', 'Алексей', 'Лиза', 'Акулина', 'Лиза', 'Василий', 'Акулина', 'Лиза', 'Настя', 'Лиза', 'Алексей', 'Лизу', 'Алексей', 'Алексей', 'Лиза', 'Алексея', 'Лиза', 'Алексей', 'Лиза', 'Лиза', 'Алексей', 'Алексей', 'Алексей', 'Лиза', 'Алексей', 'Лиза', 'Иван', 'Григорий', 'верьхом', 'Григорий', 'Иван', 'верьхом', 'Алексеем', 'Лиза', 'Григорий', 'Лиза', 'Григорий', 'Григорий', 'Лизавета', 'Настю', 'Алексей', 'Лизе', 'Григорий', 'Лиза', 'Григорий', 'Лиза', 'верьхом', 'Алексей', 'Лизы', 'Лизы', 'Лиза', 'Лиза', 'Лиза', 'Людовика', 'Алексей', 'Григорий', 'белилы', 'Алексей', 'Лиза', 'Иван', 'Григорий', 'Лизу', 'Белилы', 'Лиза', 'Лизе', 'Лиза', 'Лизу', 'Лиза', 'Лиза', 'Алексею', 'Алексей', 'Лиза', 'Алексей', 'Алексей', 'Лиза', 'Алексей', 'Лиза', 'Алексей', 'Акулин ...
# Часто встречаемые слова без имен собственных: ['.', 'Петровича', 'Белкина', ',', 'мой', 'батюшка', 'он', 'еще', 'к', 'по', 'мне', 'об', 'мы', 'хотя', 'и', 'тем', 'сего', 'было', ';', 'но', 'ей', 'нам', 'о', 'нем', 'ибо', 'вовсе', 'не', 'был', 'Она', 'Мы', 'на', 'письмо', 'его', 'как', 'а', 'вместе', 'с', 'весьма', '*', '!', 'ваше', 'от', 'месяца', 'имел', 'я', 'же', 'в', 'вы', 'свое', 'времени', 'смерти', 'также', 'моего', 'друга', 'соседа', 'С', 'вам', 'всь', 'что', 'из', 'моих', 'Петрович', 'родителей', 'году', 'отец', 'Иванович', 'Он', 'человек', 'их', 'кажется', 'В', '(', ')', 'до', 'самого', 'года', 'почти', 'время', 'село', 'свою', 'своей', 'были', 'никогда', 'она', 'всем', 'была', 'ее', 'того', 'им', 'тут', 'первый', 'год', 'себе', 'более', 'двух', 'тому', 'свои', 'однажды', 'нему', 'книги', 'стал', 'за', 'мною', 'со', 'два', 'то', 'меня', 'ту', 'самую', 'минуту', 'своем', 'тех', 'пор', 'сам', 'да', 'молодого', 'человека', 'столь', 'ко', 'самой', 'каждый', 'день', 'ни', 'образом', 'большею', 'частию', 'друг', 'может', 'которые', 'у', 'все', 'которого', 'Они', 'Однако', 'ж', 'них', 'нашего', 'моя', 'смотря', 'церкви', 'глаза', 'Вот', 'мог', 'жизни', 'Но', 'случае', 'если', 'ничего', 'самом', 'деле', 'над', 'или', 'для', ':', 'Смотритель', 'ему', 'Гробовщик', 'Я', 'ним', 'выстрел', 'вечером', 'одного', 'дома', 'где', 'своих', 'только', 'около', 'лет', 'перед', 'нами', 'наши', 'даже', 'знал', 'пешком', 'стол', 'всех', 'при', 'том', 'У', 'него', 'назад', 'бедной', 'б', 'полку', 'между', 'так', 'На', 'ли', 'отвечал', 'вопросы', 'голову', 'люди', 'нас', 'есть', 'очень', 'после', 'наконец', 'велел', 'тотчас', 'уж', 'это', 'взял', 'своему', 'продолжал', 'казалось', 'снова', 'себя', 'стола', 'который', 'успел', 'сказал', '``', 'случилось', 'доме', "''", 'уже', 'вышел', 'будет', 'угодно', 'несколько', 'минут', 'один', 'другой', 'явился', 'тот', 'Это', 'дворе', 'слова', 'три', '?', 'чрезвычайно', 'во', 'всего', 'мало', 'воображение', 'прежде', 'крайней', 'мере', 'говорил', 'мысль', 'эта', 'заметил', 'кто', 'видом', 'отобедать', 'раз', 'вас', 'непременно', 'словом', 'сторону', 'Всь', 'сели', 'скоро', 'поминутно', 'изо', 'поздно', 'При', 'руку', 'быть', 'хотел', 'Вы', 'бы', 'остановился', 'мою', 'моей', 'Так', 'мое', 'сильно', 'спросил', 'вот', 'вынул', 'молодой', 'всегда', 'Наконец', 'дал', 'тремя', 'увидел', 'должно', 'стрелять', 'руки', '...', 'под', 'Что', 'подумал', 'когда', 'ею', 'пистолет', '-', 'теперь', 'прошло', 'чтоб', 'думал', 'час', 'должна', 'некогда', 'сих', 'вперед', 'вошел', 'лошади', 'могла', 'нее', 'графиня', 'своего', 'там', 'деревню', 'они', 'отправился', 'пошел', 'давно', 'собою', 'Граф', 'начал', 'вдруг', 'чем', 'без', 'Между', 'ней', 'Да', 'А', 'хорошо', 'сказала', 'ты', 'граф', 'сиятельство', 'знаю', 'тебя', 'брат', 'Нет', 'этим', 'правда', 'Как', 'пять', 'стало', 'Не', 'нет', 'Ах', '....', 'здесь', 'этой', 'лошадь', 'домой', 'поехал', 'дело', 'эту', 'комнату', 'подошел', 'Ты', 'узнал', 'закричал', 'приехал', 'просил', 'опять', 'которой', 'каким', 'лицо', 'Вдруг', 'разве', 'тебе', 'сей', 'довольно', 'крыльцо', 'Гавриловна', 'дочери', 'всякой', 'роще', 'таким', 'свидания', 'долго', 'сад', 'через', 'сани', 'ехать', 'своим', 'ними', 'нею', 'сердце', 'вышла', 'будто', 'сын', 'часа', 'поле', 'такая', 'дорогу', 'ехал', 'старик', 'те', 'сем', 'лошадей', 'хоть', 'здоровье', 'барышня', 'дверь', 'отвечала', 'две', 'дочь', 'И', 'Кто', '..', 'Бурмин', 'которая', 'можно', 'милая', 'смотритель', 'станции', 'гробовщик', 'старый', 'Из', 'однако', 'гости', 'совсем', 'вспомнил', 'К', 'Ну', 'смотрителя', 'старого', 'барин', 'такой', 'Минский', 'барыня', 'Берестова', 'Муромский', 'Берестов', 'мисс', 'Жаксон']
